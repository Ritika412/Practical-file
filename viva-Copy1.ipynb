# %%
#Ans2
import numpy as np
x=np.array([18,9,20,9,11,1])
len(x)
import matplotlib.pyplot as p
import numpy as n
x = [-2.5, -1.5, -0.5, 0.5, 1.5, 2.5]
y = [18, 9, 5, 9, 11, 1]
p.stem(x, y)
N = (len(x)-1)/2 
n = np.array([i for i in np.arange(-N, N+1)]) 

N,n
import numpy as np
import matplotlib.pyplot as p
L = []              
l = []
tim = [i for i in np.linspace(-2.5, 2.5, 1000)]    
n = [18, 9, 5, 9, 11, 1]
for i in n:   
    for t in tim:
        term = 1
        for k in np.arange(-N, N+1):
            if k!=i:
                term = term*((t-k)/(i-k))   
        l.append(term)        
    L.append(l)     
    l=[]
for i in range(len(L)):
    p.plot(tim, L[i])
p.show()
# Out:
# F:\anaconds\lib\site-packages\ipykernel_launcher.py:9: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   if __name__ == '__main__':

# %%
#ans1
import matplotlib.pyplot as p
import numpy as np

w1 = [5* np.sin(2*np.pi*16*t) for t in np.linspace(0,1,1000)]
w2 = [5* np.cos(2*np.pi*6*t) for t in np.linspace(0,1,1000)]
w3 = [5* np.sin(2*np.pi*2000*t) for t in np.linspace(0,1,1000)]
sig=[]

for i,j,k in zip(w1,w2,w3):
    sig.append(i+j+k)
    


gt = np.fft.fft(sig)
p.plot(gt)
# Out:
# F:\anaconds\lib\site-packages\numpy\core\numeric.py:538: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
#Ans5
import thinkdsp as t
import thinkplot
from IPython.display import Audio
s1 = t.SinSignal(freq = 240, amp = 1, offset = 0)
w1 = s1.make_wave(start = 0, duration = 4, framerate = 48000)
s2 = t.SinSignal(freq = 120, amp = 2, offset = 0)
w2 = s2.make_wave(start = 0, duration = 4, framerate = 48000)
s3 = t.SinSignal(freq = 430, amp = 1, offset = 0)
w3 = s3.make_wave(start = 0, duration = 4, framerate = 48000)
s4 = t.SinSignal(freq = 337,amp = 1,offset = 0)
w4 = s4.make_wave(start = 0, duration = 4, framerate = 48000)
s5 = t.SinSignal(freq = 480,amp = 2,offset = 0)
w5 = s5.make_wave(start = 0, duration = 4, framerate = 48000)
add = w1 + w2 + w3 + w4 + w5 
audio = Audio(data = add.ys, rate = add.framerate)
audio
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import numpy as np
x=np.array([18,9,20,9,11,1])
len(x)
import matplotlib.pyplot as p
import numpy as n
x = [-2.5, -1.5, -0.5, 0.5, 1.5, 2.5]
y = [18, 9, 5, 9, 11, 1]
p.stem(x, y)
N = (len(x)-1)/2 
n = np.array([i for i in np.arange(-N, N+1)]) 

N,n
import numpy as np
import matplotlib.pyplot as p
L = []              
l = []
tim = [i for i in np.linspace(-2.5, 2.5, 1000)]    
n = [18, 9, 20, 9, 11, 1]
for i in n:   
    for t in tim:
        term = 1
        for k in np.arange(-N, N+1):
            if k!=i:
                term = term*((t-k)/(i-k))   
        l.append(term)        
    L.append(l)     
    l=[]
for i in range(len(L)):
    p.plot(tim, L[i])
p.show()
# Out:
# F:\anaconds\lib\site-packages\ipykernel_launcher.py:8: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
